# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import  mean_squared_error, r2_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\benth\AppData\Local\Temp\ipykernel_9592\793263354.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('newdata\\new_heart_data.csv')

# %%
x = data['MaxHR'].values.reshape(-1, 1)
y = data['HeartDisease']

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y, color ='green')
plt.plot(x, model.predict(x), color='red')
plt.xlabel('hr')
plt.ylabel('heart')
plt.title('fitted model')
# Out:
# Text(0.5, 1.0, 'fitted model')

# %%
total_maxhr_set = np.arange(75,191)

# %%
print(total_maxhr_set)
# Out:
# [ 75  76  77  78  79  80  81  82  83  84  85  86  87  88  89  90  91  92
#   93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110
#  111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128
#  129 130 131 132 133 134 135 136 137 138 139 140 141 142 143 144 145 146
#  147 148 149 150 151 152 153 154 155 156 157 158 159 160 161 162 163 164
#  165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182
#  183 184 185 186 187 188 189 190]

# %%
total_maxhr_data = model.predict(total_maxhr_set.reshape(-1,1))
total_maxhr_data
# Out:
# array([1.03690819, 1.02908524, 1.0212623 , 1.01343935, 1.00561641,
#        0.99779347, 0.98997052, 0.98214758, 0.97432463, 0.96650169,
#        0.95867874, 0.9508558 , 0.94303285, 0.93520991, 0.92738696,
#        0.91956402, 0.91174107, 0.90391813, 0.89609518, 0.88827224,
#        0.88044929, 0.87262635, 0.8648034 , 0.85698046, 0.84915751,
#        0.84133457, 0.83351162, 0.82568868, 0.81786573, 0.81004279,
#        0.80221984, 0.7943969 , 0.78657395, 0.77875101, 0.77092806,
#        0.76310512, 0.75528217, 0.74745923, 0.73963628, 0.73181334,
#        0.72399039, 0.71616745, 0.7083445 , 0.70052156, 0.69269861,
#        0.68487567, 0.67705272, 0.66922978, 0.66140683, 0.65358389,
#        0.64576094, 0.637938  , 0.63011505, 0.62229211, 0.61446916,
#        0.60664622, 0.59882327, 0.59100033, 0.58317738, 0.57535444,
#        0.56753149, 0.55970855, 0.5518856 , 0.54406266, 0.53623971,
#        0.52841677, 0.52059382, 0.51277088, 0.50494793, 0.49712499,
# ...

# %%
total_maxhr_factor = total_maxhr_data + 1

# %%
print(total_maxhr_factor)
# Out:
# [2.03690819 2.02908524 2.0212623  2.01343935 2.00561641 1.99779347
#  1.98997052 1.98214758 1.97432463 1.96650169 1.95867874 1.9508558
#  1.94303285 1.93520991 1.92738696 1.91956402 1.91174107 1.90391813
#  1.89609518 1.88827224 1.88044929 1.87262635 1.8648034  1.85698046
#  1.84915751 1.84133457 1.83351162 1.82568868 1.81786573 1.81004279
#  1.80221984 1.7943969  1.78657395 1.77875101 1.77092806 1.76310512
#  1.75528217 1.74745923 1.73963628 1.73181334 1.72399039 1.71616745
#  1.7083445  1.70052156 1.69269861 1.68487567 1.67705272 1.66922978
#  1.66140683 1.65358389 1.64576094 1.637938   1.63011505 1.62229211
#  1.61446916 1.60664622 1.59882327 1.59100033 1.58317738 1.57535444
#  1.56753149 1.55970855 1.5518856  1.54406266 1.53623971 1.52841677
#  1.52059382 1.51277088 1.50494793 1.49712499 1.48930204 1.4814791
#  1.47365615 1.46583321 1.45801027 1.45018732 1.44236438 1.43454143
#  1.42671849 1.41889554 1.4110726  1.40324965 1.39542671 1.38760376
# ...

# %%
total_maxhr_factor[10]
# Out:
# 1.9586787404638017

# %%
maxhr_maxhr_factor_dict = {}
for i in range(len(total_maxhr_set)):
    maxhr_maxhr_factor_dict[total_maxhr_set[i]] = total_maxhr_factor[i]

# %%
maxhr_maxhr_factor_dict[180]
# Out:
# 1.2154989722535423
