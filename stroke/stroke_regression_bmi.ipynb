# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import  mean_squared_error, r2_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\benth\AppData\Local\Temp\ipykernel_5524\793263354.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv("newdata\\new_stroke_data.csv")

# %%
x = data['bmi'].dropna()

# In NumPy-Array umwandeln und reshape
x = np.array(x).reshape(-1, 1)

y = data['stroke'].loc[data['bmi'].notna()]

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y, color ='green')
plt.plot(x, model.predict(x), color='red')
plt.xlabel('bmi')
plt.ylabel('stroke')
plt.title('fitted model')
# Out:
# Text(0.5, 1.0, 'fitted model')

# %%
total_bmi_set = np.arange(15, 51)
total_bmi_data = model.predict(total_bmi_set.reshape(-1,1))

# %%
total_bmi_factor = total_bmi_data+1

# %%
total_bmi_factor
# Out:
# array([1.02744001, 1.02852938, 1.02961875, 1.03070812, 1.03179749,
#        1.03288685, 1.03397622, 1.03506559, 1.03615496, 1.03724433,
#        1.03833369, 1.03942306, 1.04051243, 1.0416018 , 1.04269117,
#        1.04378053, 1.0448699 , 1.04595927, 1.04704864, 1.04813801,
#        1.04922738, 1.05031674, 1.05140611, 1.05249548, 1.05358485,
#        1.05467422, 1.05576358, 1.05685295, 1.05794232, 1.05903169,
#        1.06012106, 1.06121043, 1.06229979, 1.06338916, 1.06447853,
#        1.0655679 ])

# %%
bmi_bmi_factor_dict = {}
for i in range(len(total_bmi_set)):
    bmi_bmi_factor_dict[total_bmi_set[i]] = total_bmi_factor[i]

# %%
bmi_bmi_factor_dict[25]
# Out:
# 1.0383336941284038
